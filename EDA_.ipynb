# %% [markdown]
# # EXPLORATORY DATA ANALYSIS ON A DATASET

# %% [markdown]
# ## 1.	Data Cleaning and Preparation:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read the Data

# %%
or_cardio = pd.read_csv('cardiotocographic.csv')

# %% [markdown]
# ## Examine the data

# %%
or_cardio.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
or_cardio.shape
# Out:
# (2126, 14)

# %%
or_cardio.columns
# Out:
# Index(['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
#        'MLTV', 'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %%
or_cardio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
or_cardio.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %%
or_cardio.isnull()
# Out:
#          LB     AC     FM     UC     DL     DS     DP   ASTV   MSTV   ALTV  \
# 0     False  False  False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2121  False  False  False  False  False  False  False  False  False  False
# 2122  False  False  False  False  False  False  False  False  False  False
# 2123  False  False  False  False  False  False  False  False  False  False
# 2124  False  False  False  False  False  False  False  False  False  False
# 2125  False  False  False  False  False  False  False  False  False  False
#
#        MLTV  Width  Tendency    NSP
# ...

# %%
or_cardio.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %% [markdown]
# ## Analyze Columns

# %%
or_cardio.head(5)
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
cardio = or_cardio.copy()

# %% [markdown]
# ## Handle null values

# %%
cardio.isnull()
# Out:
#          LB     AC     FM     UC     DL     DS     DP   ASTV   MSTV   ALTV  \
# 0     False  False  False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2121  False  False  False  False  False  False  False  False  False  False
# 2122  False  False  False  False  False  False  False  False  False  False
# 2123  False  False  False  False  False  False  False  False  False  False
# 2124  False  False  False  False  False  False  False  False  False  False
# 2125  False  False  False  False  False  False  False  False  False  False
#
#        MLTV  Width  Tendency    NSP
# ...

# %%
sns.heatmap(cardio.isnull())
plt.show()

# %%
cardio.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
cardio.fillna({
    'LB': cardio['LB'].mean(),
    'AC': cardio['AC'].mean(),
    'DS': cardio['DS'].mean(),
    'DP': cardio['DP'].mean(),
    'MLTV': cardio['MLTV'].mean(),
    'Width': cardio['Width'].mean(),
    'Tendency': cardio['Tendency'].mean(),
    'NSP': cardio['NSP'].mean()
}, inplace = True)

# %%
cardio.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
sns.heatmap(cardio.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ## Check for Outliers

# %%
sns.catplot(data = cardio, kind = 'box')
plt.show()

# %%
q1 = cardio['LB'].quantile(0.25)
q3 = cardio['LB'].quantile(0.75)
IQR = q3 - q1

# %%
q1, q3, IQR
# Out:
# (126.0, 140.0, 14.0)

# %%
ulimit = q3 + 1.5 * IQR
llimit = q1 - 1.5 * IQR

llimit, ulimit
# Out:
# (105.0, 161.0)

# %%
cardio['LB_U'] = cardio['LB'].apply(
    lambda x: ulimit if x > ulimit else (llimit if x < llimit else x)
)

# %%
q1 = cardio['ASTV'].quantile(0.25)
q3 = cardio['ASTV'].quantile(0.75)
IQR = q3 - q1

# %%
q1, q3, IQR
# Out:
# (32.0, 61.0, 29.0)

# %%
ulimit = q3 + 1.5 * IQR
llimit = q1 - 1.5 * IQR

llimit, ulimit
# Out:
# (-11.5, 104.5)

# %%
cardio['ASTV_U'] = cardio['ASTV'].apply(
    lambda x: ulimit if x > ulimit else (llimit if x < llimit else x)
)

# %%
cardio[cardio['ASTV'] != cardio['ASTV_U']]
# Out:
#               LB        AC        FM        UC        DL        DS   DP  \
# 131   158.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 232   123.000000  0.003650  0.005474  0.000000  0.000000  0.000000  0.0
# 345   139.000000 -0.000007  0.006593  0.000000  0.000000  0.000000  0.0
# 504   128.000000  0.008253  0.013755  0.004127  0.000000  0.000000  0.0
# 1014  139.000000  0.006312  0.000000  0.004509  0.000000  0.000000  0.0
# 1027   51.842487  0.009485  0.000000  0.005420  0.002710  0.000005  0.0
# 1195  138.000000  0.011752  0.000000  0.005342  0.000000  0.000000  0.0
# 1578  132.000000  0.000000 -0.002889  0.002994  0.000074  0.000000  0.0
# 1941  133.000000  0.000000  0.003562  0.006233  0.003562  0.000000  0.0
# 2008  125.000000  0.001196  0.001196  0.008373  0.009569  0.000000  0.0
#
#        ASTV  MSTV  ALTV       MLTV       Width  Tendency      NSP   LB_U  \
# 131   -63.0   0.6  31.0   8.600000   92.000000       1.0  1.00000  158.0
# ...

# %%
q1 = cardio['MSTV'].quantile(0.25)
q3 = cardio['MSTV'].quantile(0.75)
IQR = q3 - q1

# %%
q1, q3, IQR
# Out:
# (0.7, 1.7, 1.0)

# %%
cardio['MSTV'].describe()
# Out:
# count    2126.000000
# mean        1.364378
# std         1.173632
# min        -6.600000
# 25%         0.700000
# 50%         1.200000
# 75%         1.700000
# max        13.800000
# Name: MSTV, dtype: float64

# %%
ulimit = q3 + 1.5 * IQR
llimit = q1 - 1.5 * IQR

llimit, ulimit
# Out:
# (-0.8, 3.2)

# %%
cardio['MSTV_U'] = cardio['MSTV'].apply(
    lambda x: ulimit if x > ulimit else (llimit if x < llimit else x)
)

# %%
q1 = cardio['ALTV'].quantile(0.25)
q3 = cardio['ALTV'].quantile(0.75)
IQR = q3 - q1

# %%
q1, q3, IQR
# Out:
# (0.0, 11.0, 11.0)

# %%
ulimit = q3 + 1.5 * IQR
llimit = q1 - 1.5 * IQR

llimit, ulimit
# Out:
# (-16.5, 27.5)

# %%
cardio['ALTV_U'] = cardio['ALTV'].apply(
    lambda x: ulimit if x > ulimit else (llimit if x < llimit else x)
)

# %%
q1 = cardio['MLTV'].quantile(0.25)
q3 = cardio['MLTV'].quantile(0.75)
IQR = q3 - q1

# %%
q1, q3, IQR
# Out:
# (4.6, 10.8, 6.200000000000001)

# %%
ulimit = q3 + 1.5 * IQR
llimit = q1 - 1.5 * IQR

llimit, ulimit
# Out:
# (-4.700000000000001, 20.1)

# %%
cardio['MLTV_U'] = cardio['MLTV'].apply(
    lambda x: ulimit if x > ulimit else (llimit if x < llimit else x)
)

# %%
q1 = cardio['Width'].quantile(0.25)
q3 = cardio['Width'].quantile(0.75)
IQR = q3 - q1

# %%
ulimit = q3 + 1.5 * IQR
llimit = q1 - 1.5 * IQR

llimit, ulimit
# Out:
# (-57.5, 194.5)

# %%
cardio['Width_U'] = cardio['Width'].apply(
    lambda x: ulimit if x > ulimit else (llimit if x < llimit else x)
)

# %%
cardio.columns
# Out:
# Index(['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
#        'MLTV', 'Width', 'Tendency', 'NSP', 'LB_U', 'ASTV_U', 'MSTV_U',
#        'ALTV_U', 'MLTV_U', 'Width_U'],
#       dtype='object')

# %%
q1 = cardio['AC'].quantile(0.25)
q3 = cardio['AC'].quantile(0.75)
IQR = q3 - q1

# %%
ulimit = q3 + 1.5 * IQR
llimit = q1 - 1.5 * IQR

llimit, ulimit
# Out:
# (-0.00840919125, 0.01401531875)

# %%
cardio['AC_U'] = cardio['AC'].apply(
    lambda x: ulimit if x > ulimit else (llimit if x < llimit else x)
)

# %%
q1 = cardio['FM'].quantile(0.25)
q3 = cardio['FM'].quantile(0.75)
IQR = q3 - q1

# %%
ulimit = q3 + 1.5 * IQR
llimit = q1 - 1.5 * IQR

llimit, ulimit
# Out:
# (-0.003849856875, 0.006416428125)

# %%
cardio['FM_U'] = cardio['FM'].apply(
    lambda x: ulimit if x > ulimit else (llimit if x < llimit else x)
)

# %%
q1 = cardio['UC'].quantile(0.25)
q3 = cardio['UC'].quantile(0.75)
IQR = q3 - q1

# %%
ulimit = q3 + 1.5 * IQR
llimit = q1 - 1.5 * IQR

llimit, ulimit
# Out:
# (-0.005177445124999999, 0.013563983874999998)

# %%
cardio['UC_U'] = cardio['UC'].apply(
    lambda x: ulimit if x > ulimit else (llimit if x < llimit else x)
)

# %%
q1 = cardio['DL'].quantile(0.25)
q3 = cardio['DL'].quantile(0.75)
IQR = q3 - q1

# %%
ulimit = q3 + 1.5 * IQR
llimit = q1 - 1.5 * IQR

llimit, ulimit
# Out:
# (-0.004934211, 0.008223685)

# %%
cardio['DL_U'] = cardio['DL'].apply(
    lambda x: ulimit if x > ulimit else (llimit if x < llimit else x)
)

# %%
q1 = cardio['DS'].quantile(0.25)
q3 = cardio['DS'].quantile(0.75)
IQR = q3 - q1

# %%
ulimit = q3 + 1.5 * IQR
llimit = q1 - 1.5 * IQR

llimit, ulimit
# Out:
# (0.0, 0.0)

# %%
cardio['DS_U'] = cardio['DS'].apply(
    lambda x: ulimit if x > ulimit else (llimit if x < llimit else x)
)

# %%
q1 = cardio['DP'].quantile(0.25)
q3 = cardio['DP'].quantile(0.75)
IQR = q3 - q1

# %%
ulimit = q3 + 1.5 * IQR
llimit = q1 - 1.5 * IQR

llimit, ulimit
# Out:
# (0.0, 0.0)

# %%
cardio['DP_U'] = cardio['DP'].apply(
    lambda x: ulimit if x > ulimit else (llimit if x < llimit else x)
)

# %%
q1 = cardio['Tendency'].quantile(0.25)
q3 = cardio['Tendency'].quantile(0.75)
IQR = q3 - q1

# %%
ulimit = q3 + 1.5 * IQR
llimit = q1 - 1.5 * IQR

llimit, ulimit
# Out:
# (-1.5, 2.5)

# %%
cardio['Tendency_U'] = cardio['Tendency'].apply(
    lambda x: ulimit if x > ulimit else (llimit if x < llimit else x)
)

# %%
cardio.drop('MSTV', axis = 1, inplace = True)
cardio.drop('ALTV', axis = 1, inplace = True)
cardio.drop('MLTV', axis = 1, inplace = True)
cardio.drop('AC', axis = 1, inplace = True)
cardio.drop('LB', axis = 1, inplace = True)
cardio.drop('Width', axis = 1, inplace = True)
cardio.drop('ASTV', axis = 1, inplace = True)
cardio.drop('UC', axis = 1, inplace = True)
cardio.drop('DL', axis = 1, inplace = True)
cardio.drop('DS', axis = 1, inplace = True)
cardio.drop('DP', axis = 1, inplace = True)
cardio.drop('Tendency', axis = 1, inplace = True)
cardio.drop('FM', axis = 1, inplace = True)

# %%
cardio['DP_U'].unique()
# Out:
# array([0.])

# %%
sns.catplot(data = cardio, kind='box')
plt.show()

# %%
cardio
# Out:
#            NSP        LB_U  ASTV_U  MSTV_U  ALTV_U  MLTV_U  Width_U      AC_U  \
# 0     2.000000  120.000000    73.0     0.5    27.5     2.4     64.0  0.000000
# 1     1.000000  132.000000    17.0     2.1     0.0    10.4    130.0  0.006380
# 2     1.000000  133.000000    16.0     2.1     0.0    13.4    130.0  0.003322
# 3     1.000000  134.000000    16.0     2.4     0.0    20.1    117.0  0.002561
# 4     1.000000  131.948232    16.0     2.4     0.0    19.9    117.0  0.006515
# ...        ...         ...     ...     ...     ...     ...      ...       ...
# 2121  2.000000  140.000000    79.0     0.2    25.0     7.2     40.0  0.000000
# 2122  2.000000  140.000000    78.0     0.4    22.0     7.1     66.0  0.000775
# 2123  1.990464  140.000000    79.0     0.4    20.0     6.1     67.0  0.000980
# 2124  2.000000  140.000000    78.0     0.4    27.0     7.0     66.0  0.000679
# 2125  1.000000  142.000000    74.0     0.4    27.5     5.0     42.0  0.001616
#
# ...

# %%
cardio['DS_U'].sum()
# Out:
# 0.0

# %%
cardio['DP_U'].sum()
# Out:
# 0.0

# %%
cardio['FM_U'].sum()
# Out:
# 3.3331472963749995

# %% [markdown]
# ## Remove unwanted columns

# %%
cardio.drop(columns=['FM_U'], inplace = True)

# %%
cardio.drop(columns=['DP_U'], inplace = True)

# %%
cardio.drop(columns=['DS_U'], inplace = True)

# %%
cardio.shape
# Out:
# (2126, 11)

# %% [markdown]
# ## 2. Statistical Summary:

# %%
cardio.describe()
# Out:
#                NSP         LB_U       ASTV_U       MSTV_U       ALTV_U  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean      1.304507   133.293725    46.981873     1.304644     6.691678
# std       0.641426     9.930227    17.612745     0.781091    10.378400
# min      -1.025988   105.000000   -11.500000    -0.800000   -16.500000
# 25%       1.000000   126.000000    32.000000     0.700000     0.000000
# 50%       1.000000   133.000000    49.000000     1.200000     0.000000
# 75%       1.000000   140.000000    61.000000     1.700000    11.000000
# max       5.000000   161.000000   104.500000     3.200000    27.500000
#
#             MLTV_U      Width_U         AC_U         UC_U         DL_U  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean      8.016212    70.321076     0.003147     0.004362     0.001770
# std       5.046784    39.570633     0.003826     0.003001     0.002668
# ...

# %% [markdown]
# #### NSP (Target Value): Some values are negative, which might be mistakes.
# #### ASTV_U & MSTV_U (Heart Rate Changes): Have negative values, which is not normal.
# #### ALTV_U & MLTV_U (Heart Rate Variability): Change a lot, and some values are negative.
# #### Width_U (Signal Range): Varies a lot, from -57.5 to 194.5, showing big differences.

# %% [markdown]
# ### 3.	Data Visualization:

# %% [markdown]
# ### histograms to visualize the distributions of various numerical variables.

# %%
histogram = cardio[['LB_U', 'ASTV_U', 'MSTV_U', 'ALTV_U', 'MLTV_U', 'Width_U', 'AC_U', 'UC_U', 'DL_U', 'Tendency_U']].hist(bins=10, figsize=(10, 7))
plt.tight_layout()
plt.show()a

# %% [markdown]
# ### Bar Chart to display the frequency of categories for categorical variables

# %%
nsp_counts = cardio['NSP'].value_counts()

plt.bar(nsp_counts.index, nsp_counts.values)

plt.xlabel('NSP')
plt.ylabel('Frequency')
plt.title('Frequency of Categories in NSP')
plt.show()

# %% [markdown]
# ###  correlation heatmaps to explore relationships between pairs of variables.

# %%
corr_matrix = cardio.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
sns.set_palette('viridis')

sns.set_style(style='whitegrid')
sns.pairplot(cardio)
plt.show()

# %%
print(cardio['Tendency_U'].dtype)
# Out:
# float64

# %%
print(cardio['Tendency_U'].unique())
# Out:
# [ 9.99926014e-01  0.00000000e+00  1.00000000e+00 -1.00000000e+00
#   1.10922950e-02  3.28970400e-03  3.16371404e-01  9.87842382e-01
#   8.28090200e-03 -2.59343380e-02  1.00607149e+00 -5.99107200e-03
#  -1.00661422e+00 -6.47057600e-03  1.22923530e-02 -1.21476810e-02
#  -3.78846800e-03  4.42943800e-03  1.00312902e+00  9.81337890e-01
#   9.85729402e-01  1.88044200e-03  1.19756210e-02  2.38459500e-03
#  -1.50000000e+00  2.13996940e-02  9.71151191e-01 -1.00210848e+00
#   1.00124823e+00  6.55067600e-03 -9.94488285e-01  9.71445618e-01
#  -4.25352300e-03 -9.97403600e-03 -2.66400120e-02 -1.98864410e-02
#  -1.89944450e-02 -1.48017800e-03  8.13726100e-03 -3.07942200e-03
#  -5.19414200e-03 -9.91883608e-01  9.84422685e-01  1.08158800e-02
#   1.00184071e+00  1.00308374e+00  1.00793862e+00  9.73593786e-01
#   2.77565750e-02 -3.93738800e-03  1.00442756e+00  9.84996964e-01
#  -3.52216290e-02 -8.17900600e-03  9.93192350e-01  9.88563525e-01
# ...

# %% [markdown]
# ## 4.	Pattern Recognition and Insights:

# %% [markdown]
# ## Correlation :

# %% [markdown]
# #### Width_U and MSTV_U have a strong positive relationship (0.65)
# #### DL_U and MSTV_U have a moderate to strong positive relationship (0.57)
# #### Width and DL_U have a moderate to strong positive relationship (0.51)
# #### ALTV_U and MSTV_U have a strong negative relationship (-0.54)
# #### ALTV_U and Width_U have a moderate negative relationship (-0.44)

# %% [markdown]
# ## Trends/Patterns:

# %% [markdown]
# #### If the data is collected over time (temporal data), we can analyze variables like 'LB_U', 'ASTV_U', 'MSTV_U', 'ALTV_U', 'MLTV_U',
# #### 'Width_U', 'AC_U', 'UC_U', 'DL_U', 'Tendency_U to see if they show patterns (e.g. regular increases or decreases)

# %% [markdown]
# ## 5.	Conclusion:

# %% [markdown]
# ## Key Insights:

# %% [markdown]
# #### Some variables are closely related, and this is worth studying more to understand why.

# %% [markdown]
# ## Impact:

# %% [markdown]
# #### Knowing these relationships can help predict future changes and make smarter decisions to improve results.
